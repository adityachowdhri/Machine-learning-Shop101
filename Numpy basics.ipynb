# %%
import numpy as np

# %%
a=np.array([1,2,3],dtype="int8" )
print(a)
# Out:
# [1 2 3]

# %%
b=np.array([[9.0,8.0,7.0],[7.0,50.0,60.]])
print(b)
# Out:
# [[ 9.  8.  7.]
#  [ 7. 50. 60.]]

# %%
#dimension
b.ndim
# Out:
# 2

# %%
#shape
b.shape
# Out:
# (2, 3)

# %%
# get type
b.dtype
a.dtype
# Out:
# dtype('int16')

# %%
#get size
a.itemsize
b.itemsize
# Out:
# 8

# %%
#get total size
a.nbytes
# Out:
# 3
